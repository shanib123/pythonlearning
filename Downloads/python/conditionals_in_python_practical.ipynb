# %% [markdown]
# # Conditional Statements in Python — Practical Notebook
#
# Conditional statements let your program make decisions — running different code depending on whether something is `True` or `False`. This is the first building block you'll use constantly in data work: checking values, flagging missing data, validating inputs, and classifying results.

# %% [markdown]
# ## `if` — run code only when a condition is true
#
# If the condition is `True`, the indented block runs. If it's `False`, Python simply skips it.

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("You are eligible to vote")
# Out:
# Enter your age: 12

# %% [markdown]
# ## `if` / `else` — choose between two outcomes
#
# When the condition is `True`, the `if` block runs. When it's `False`, the `else` block runs instead. Exactly one of the two always executes.

# %%
marks = int(input("enter score: "))
if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# enter score: 0
# Fail

# %% [markdown]
# ## `if` / `elif` / `else` — choose between several outcomes
#
# Python checks each condition in order and runs the first one that's `True`. If none of them are true, the final `else` runs.

# %%
score = int(input("enter ur score: "))
if score >= 90:
    print("Grade A")
elif score >= 75:
    print("Grade B")
elif score >= 60:
    print("Grade C")
else:
    print("Grade D")
# Out:
# enter ur score: 75
# Grade B

# %% [markdown]
# ## Conditions inside conditions
#
# A conditional block can contain another conditional inside it — useful when a decision depends on more than one check happening in sequence.

# %%
age = 12
has_id = True

if age >= 18:
    if has_id:
        print("Entry allowed")
    else:
        print("ID required")
else:
    print("Entry denied")
# Out:
# Entry denied

# %% [markdown]
# ## Combining more than one condition
#
# You can join conditions together instead of nesting them, using the logical operators covered earlier.

# %%
temperature = 30
is_raining = True

if temperature > 25 and not is_raining:
    print("Good day for a walk")

# %%
cgpa = 8.2
backlogs = 0

if cgpa >= 7.5 or backlogs == 0:
    print("Eligible for placement")

# %% [markdown]
# ## A data-checking example
#
# Before doing anything with a value, it often helps to check what state it's in first — this is a pattern you'll use constantly when working with real datasets.

# %%
column_value = None

if column_value is None:
    print("Missing value detected")
# Out:
# Missing value detected

# %%
current_type = "int64"
allowed_types = ["int64", "float64"]

if current_type in allowed_types:
    print("Valid numeric column type")
else:
    print("Unsupported column type")
# Out:
# Valid numeric column type

# %% [markdown]
# ---
# ## Practice Questions

# %% [markdown]
# **Q1.** A student's score is 42. The passing mark is 40. Print whether the student has passed or failed.

# %%
marks = 42
if marks >=40:
    print("student has passed")
# Out:
# student has passed

# %% [markdown]
# **Q2.** A temperature reading is 38.5. A reading above 37.5 is considered a fever. Print whether this reading indicates a fever.

# %%
temperature_reading = 38.5
if temperature_reading > 37.5:
    print("fever")
# Out:
# fever

# %% [markdown]
# **Q3.** A dataset column value is stored as `column_value = None`. Print a message saying whether this value is missing.

# %%
coloumn_value = None 
if coloumn_value is None:
    print("the value is missing")
# Out:
# the value is missing

# %% [markdown]
# **Q4.** An exam score is 88. Using these bands — 90 and above: "A", 75 to 89: "B", 60 to 74: "C", below 60: "D" — print the grade for this score.

# %%
exam_score = 88
if exam_score>=90:
    print("Grade A")
elif exam_score>=75:
    print("Grade B")
elif exam_score>=60:
    print("Grade C")
elif exam_score<60:
    print("Grade D")
# Out:
# Grade B

# %% [markdown]
# **Q5.** A user's age is 16. Only users aged 18 and above can register on a platform. Print whether this user is allowed to register.

# %%
age = 16
if age >=18:
    print("user is allowed to register")
else:
    print("not allowed to register")
# Out:
# not allowed to register

# %% [markdown]
# **Q6.** A bank account balance is 500 and a withdrawal request is for 700. Print whether the withdrawal can be processed.

# %%
balance = 500
if balance>=700:
    print("Withdrawal cna be proccessed")
else:
    print("Withdrawal cant be proccessed")
# Out:
# Withdrawal cant be proccessed

# %% [markdown]
# **Q7.** A dataset column's type is stored as `column_type = "float64"`. The numeric types accepted are `"int64"` and `"float64"`. Print whether this column type is numeric.

# %%
column_type = "float64"
allowed_type = ["int64" , "float64"]
if column_type in allowed_type :
    print("this column type is numeric")
else:
    print("this column is not numeric")
# Out:
# this column type is numeric

# %% [markdown]
# **Q8.** A movie is rated suitable only for viewers aged 13 and above. A viewer's age is 15. Print whether they are allowed to watch it.

# %%
age =15
if age >=13:
    print("they are allowed to watch")
else:
    print("they are not allowed to watch")
# Out:
# they are allowed to watch

# %% [markdown]
# **Q9.** A model's accuracy is 0.82. A model is considered good only when its accuracy is 0.80 or higher. Print whether this model meets that standard.

# %%
accuracy = 0.82
if accuracy >=0.80:
    print("this model meets the standard")
else:
    print("not meets the standard")
# Out:
# this model meets the standard

# %% [markdown]
# **Q10.** A survey response records `is_satisfied = True` and `would_recommend = True`. Print whether this response counts as a strong positive review, which requires both to be true.

# %%
is_satisfied = True
would_recommend = True
if is_satisfied and would_recommend :
    print("psitive response")
else:
    print("negetive response")
# Out:
# psitive response

# %% [markdown]
# **Q11.** A file's extension is stored as `extension = "csv"`. Only `"csv"` and `"xlsx"` files can be read as tabular data. Print whether this file can be read directly.

# %%
extension = "csv"
tabular_data = ["csv""xlsx"]
if extension in tabular_data:
    print("can be read directly")
else:
    print("cant be read")
# Out:
# cant be read

# %% [markdown]
# **Q12.** A room's humidity reading is 85. Readings above 70 are "Humid", between 40 and 70 are "Comfortable", and below 40 are "Dry". Print the comfort level for this reading.

# %%
humidity_reading = 85
if humidity_reading >70:
    print("Humid")
elif humidity_reading >40:
    print("Comfortable")
elif humidity_reading <40:
    print("Dry")
# Out:
# Humid

# %%
password =input("enter the password")
if password == "Route@2026":
    print("correct password")
else:
    print("Not corrrect")
# Out:
# correct password

# %%
password =input("enter the password")
if len(password)==8:
    print("accept")
else:
    print("reject")
# Out:
# reject

# %%
a = input("enter the word")
if a == a[::-1]:
    print("its palidrome")
else:
    print("its not a palidrome")
# Out:
# its palidrome

# %% [markdown]
# ###Check entered mobile number valid or not(should be 10 digits)- shows reason if not valid

# %%
a =input("enter your mobiile number")
if len(a)==10 and a.isdigit():
    print("its valid no")
else:
    print("its not valid")
# Out:
# its not valid

# %%
a = int(input("enter a number"))
if a/2 and a%2 == 0:
   print("can divisible ")
else:
   print("cant divisible")
# Out:
# cant divisible
