# %% [markdown]
# #python string

# %% [markdown]
# ### create a string and print its first and last charcter

# %%
name="muhammed shanib"
print("first letter:",name[0])
print("last letter:",name[-1])
# Out:
# first letter: m
# last letter: b

# %% [markdown]
# ### Reverse a string using slicing

# %%
a="routeupskills"
print(a[::-1])
# Out:
# sllikspuetuor

# %% [markdown]
# ### count the number of occurence

# %%
a="banana"
print(a.count("a"))
# Out:
# 3

# %% [markdown]
# ### replace "java" with "python" from "python is simple & powerfull".

# %%
a="java is simple & powerfull"
print(a.replace("java","python"))
# Out:
# python is simple & powerfull

# %% [markdown]
# ### convert a string to uppercase and lowercase

# %%
name="Muhammed Shanib"
print(name.upper())
print(name.lower())
print(name.capitalize())
# Out:
# MUHAMMED SHANIB
# muhammed shanib
# Muhammed shanib

# %% [markdown]
# ### split "python,java,SQL" into a list

# %%
text="Python,java,SQL"
print(text.split(","))
# Out:
# ['Python', 'java', 'SQL']

# %% [markdown]
# ### join["python","java","SQL"] using "-".

# %%
text=['Python', 'java', 'SQL']
print("-".join(text))
# Out:
# Python-java-SQL

# %% [markdown]
# ### check whether "thon" exist in "python"

# %%
text="python"
print("thon" in "python")
# Out:
# True

# %% [markdown]
# ### print every second character form "programming".

# %%
text="programming"
print(text[1::2])
# Out:
# rgamn

# %% [markdown]
# ### collect deatils like first name, last name, dob, place, weight, Height, number, mail id , etc and print ina structured format

# %%
name1=(input("enter your first name"))
name2=(input("enter your last name"))
Birth_year=int(input("enter your birthyear"))
place=(input("enter your place"))
weight=int(input("enter your weight"))
height=int(input("enter your height"))
Number=int(input("enter your conatct no"))
mail_id=(input("enter your mail id"))
print("STUDENT DETAILS""\n"
      "."*12"\n"
      )
# Out:
# STUDENT DETAILS
# ..........
# Full name: MuhammedShanib
# Age: 21
# Place: Mannarkkad
# Weight: 65
# Height: 76
# Contact no: 7510240724
# EmailID: shnibadyusdyu@gmail.com
