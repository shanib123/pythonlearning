# %% [markdown]
# ###Store the name of your favourite hobby and how many hours a week you spend on
# it, then print both together in one sentence.

# %%
hobby = "reading books"
hour = 1
print("My favourite hobby is",hobby,"and i spend",hour,"hour in a day")
# Out:
# My favourite hobby is reading books and i spend 1 hour in a day

# %% [markdown]
# ###Ask the user to enter their favourite season and print a short reaction message that
# includes it.

# %%
season_message = input("enter your favourite season meassge")
print(season_message,"its very nice")
# Out:
# rainy season its very nice

# %% [markdown]
# ###A queue token number is received as text at a service counter, for example "128".
# Confirm what type this value is when it's received, then convert it to a number and print
# the next token number to be called.

# %%
token_no = "128"
print(type(token_no))
print(int(token_no))
print(129)
# Out:
# <class 'str'>
# 128
# 129
