# %% [markdown]
# # Dictionaries in Python — Practical Notebook

# %% [markdown]
# ## Creating Dictionaries

# %%
my_dict = {}
print(my_dict)
type(my_dict)
# Out:
# {}
# dict

# %%
student = {"name": "Riya", "age": 21, "course": "Python"}
print(student)
# Out:
# {'name': 'Riya', 'age': 21, 'course': 'Riya'}

# %%
person = dict(name="Aman", age=25)
print(person)
# Out:
# {'name': 'Aman', 'age': 25}

# %%
employee = {"name": "Kiran", "address": {"city": "Kochi", "pin": "682001"}}
print(employee)
# Out:
# {'name': 'Kiran', 'address': {'city': 'Kochi', 'pin': '682001'}}

# %% [markdown]
# ## Accessing Values

# %%
student = {"name": "Riya", "age": 21, "course": "Python"}
print(student["name"])
# Out:
# Riya

# %%
print(student.get("p"))
# Out:
# None

# %%
print(student.get("grade", "Not Found"))
# Out:
# Not Found

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'course'])

# %%
print(student.values())
# Out:
# dict_values(['Riya', 21, 'Python'])

# %%
print(student.items())
# Out:
# dict_items([('name', 'Riya'), ('age', 21), ('course', 'Python')])

# %%
print("place" in student)
# Out:
# False

# %%
print(len(student))
# Out:
# 3

# %% [markdown]
# ## Modifying Dictionaries

# %%
student = {"name": "Riya", "age": 21}
student["age"] = 22
print(student)
# Out:
# {'name': 'Riya', 'age': 22}

# %%
student = {"name": "Riya", "age": 21}
student["grade"] = "A"
print(student)
# Out:
# {'name': 'Riya', 'age': 21, 'grade': 'A'}

# %%
student = {"name": "Riya", "age": 21}
student.update({"age": 23, "grade": "A"})
print(student)
# Out:
# {'name': 'Riya', 'age': 23, 'grade': 'A'}

# %%
student = {"name": "Riya", "age": 21, "course": "Python"}
removed = student.pop("course")
print(student)
# Out:
# {'name': 'Riya', 'age': 21}

# %%
student = {"name": "Riya", "age": 21}
last = student.popitem()
print(student, last)
# Out:
# {'name': 'Riya'} ('age', 21)

# %%
student = {"name": "Riya", "age": 21}
student.clear()
print(student)
# Out:
# {}

# %% [markdown]
# ## Combining Dictionaries

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}
combined = {**dict1, **dict2}
print(combined)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# ## Converting Between Types

# %%
student = {"name": "Riya", "age": 21, "course": "Python"}
print(list(student.keys()))
# Out:
# ['name', 'age', 'course']

# %%
print(list(student.items()))
# Out:
# [('name', 'Riya'), ('age', 21), ('course', 'Python')]

# %%
names = ["Riya", "Aman", "Kiran"]
marks = [88, 76, 91]
paired = dict(zip(names, marks))
print(paired)
# Out:
# {'Riya': 88, 'Aman': 76, 'Kiran': 91}

# %% [markdown]
# ## Dictionary Comprehension

# %%
squares = {x: x*x for x in range(5)}
print(squares)

# %% [markdown]
# ---
# ## Practice Questions

# %% [markdown]
# **Q1.** A student's report card is `{"Math": 88, "Science": 92, "English": 79}`. Print the marks scored in Science.

# %%
students_report = {"Math": 88, "science": 92, "English":79}
print(students_report["science"])
# Out:
# 92

# %% [markdown]
# **Q2.** A user's profile is `{"username": "kiran_23", "email": "kiran23@gmail.com", "age": 24}`. Print all the keys used in this profile.

# %%
users_profile = {"username": "Kiran_23", "email" : "kiran@gmail.com", "age": 24}
print(users_profile.keys())
# Out:
# dict_keys(['username', 'email', 'age'])

# %% [markdown]
# **Q3.** A shop's inventory is `{"Pen": 50, "Notebook": 30, "Eraser": 100}`. The pen stock just got updated to 65 after a new delivery — update the dictionary and print it.

# %%
shops_inventory = {"pen": 50, "Notebook": 30 , "Eraser": 100}
shops_inventory["pen"]=60
print(shops_inventory)
# Out:
# {'pen': 60, 'Notebook': 30, 'Eraser': 100}

# %% [markdown]
# **Q4.** A movie's details are `{"title": "Inception", "year": 2010, "rating": 8.8}`. Add a new key `"director"` with value `"Christopher Nolan"` and print the updated dictionary.

# %%
a= {"title": "Inception", "year" : 2010 , "rating": 8.8}
b = a["Director"] = "christopher Nolan"
print(a)
# Out:
# {'title': 'Inception', 'year': 2010, 'rating': 8.8, 'Director': 'christopher Nolan'}

# %% [markdown]
# **Q5.** A restaurant menu is `{"Pizza": 250, "Burger": 150, "Pasta": 200}`. `"Burger"` is no longer available — remove it from the menu and print the updated menu.

# %%
menu = {"pizza": 250, "Burger":150, "pasta": 200}
menu.pop("Burger")
print(menu)
# Out:
# {'pizza': 250, 'pasta': 200}

# %% [markdown]
# **Q6.** A contact book is `{"Mom": "9998887771", "Dad": "9998887772", "Friend": "9998887773"}`. Check whether `"Sister"` is a saved contact.

# %%
a = {"Mom": "9998887771", "Dad": "9998887772", "Friend": "9998887773"}
print("Sister" in a)
# Out:
# False

# %% [markdown]
# **Q7.** A store records its daily sales as `{"Monday": 3200, "Tuesday": 2800, "Wednesday": 4100}`. Print the total sales across all three days.

# %%
a = {"Monday": 3200, "Tuesday":2800, "Wednesday": 4100}
print(sum(a.values()))
# Out:
# 10100

# %% [markdown]
# **Q8.** Two friends maintain separate contact books: `contacts1 = {"Ravi": "9991112223"}` and `contacts2 = {"Meera": "9994445556"}`. Combine both into a single contact book and print it.

# %%
contacts1 = {"Ravi": "9991112223"}
contacts2 = {"Meera": "9994445556"}
a = {**contacts1,**contacts2}
print(a)
# Out:
# {'Ravi': '9991112223', 'Meera': '9994445556'}

# %% [markdown]
# **Q9.** A teacher recorded student names as `["Riya", "Aman", "Kiran"]` and their marks as `[88, 76, 91]`, in matching order. Combine them into a single dictionary pairing each name with their mark, and print it.

# %%
name = ["riya", "Aman" , "Kiran"]
marks = [88, 76 , 91]
a = dict(zip(name,marks))
print(a)
# Out:
# {'riya': 88, 'Aman': 76, 'Kiran': 91}

# %% [markdown]
# **Q10.** A quiz stores each question as a key with its correct answer as the value: `{"2+2": "4", "Capital of France": "Paris", "Largest Ocean": "Pacific"}`. Print only the questions, without their answers.

# %%
quiz = {"2+2": "4", "Capital of France": "Paris", "Largest Ocean": "Pacific"}
print(quiz.keys())
# Out:
# dict_keys(['2+2', 'Capital of France', 'Largest Ocean'])
