# %% [markdown]
# # Sets in Python — Practical Notebook

# %% [markdown]
# ## Creating Sets

# %%
my_set = set(('a','b','c'))
print(my_set)
type(my_set)
# Out:
# {'a', 'c', 'b'}
# set

# %%
fruits = {"Apple", "Banana", "Mango", "Apple"}
print(fruits)
# Out:
# {'Mango', 'Apple', 'Banana'}

# %%
num = [1,2,3,4,2,3,2,3,4,3,4,5,67,9]
list(set(num))
# Out:
# [1, 2, 3, 4, 5, 67, 9]

# %%
numbers = {1, 2, 2, 3, 3, 3}
print(numbers)
# Out:
# {1, 2, 3}

# %%
colors = set(["Red", "Green", "Blue"])
print(colors)
# Out:
# {'Blue', 'Red', 'Green'}

# %%
days = set(("Mon", "Tue", "Wed"))
print(days)
# Out:
# {'Mon', 'Tue', 'Wed'}

# %% [markdown]
# ## Set Methods

# %%
my_set = {1, 2, 3}
my_set.add(4)
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
my_set = {1, 2}
my_set.update([3, 4, 5])
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set = {1, 2, 3}
my_set.remove(2)
print(my_set)
# Out:
# {1, 3}

# %%
my_set = {1, 2, 3}
my_set.discard(5)
print(my_set)
# Out:
# {2, 3}

# %%
my_set = {1, 2, 3}
removed = my_set.pop()
print(my_set)
print(removed)
# Out:
# {2, 3}
# 1

# %%
my_set = {1, 2, 3}
my_set.clear()
print(my_set)
# Out:
# set()

# %% [markdown]
# ## Set Operations

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}
print(a | b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(a & b)
# Out:
# {3, 4}

# %%
print(a - b)
# Out:
# {1, 2}

# %%
print(a ^ b)
# Out:
# {1, 2, 5, 6}

# %% [markdown]
# ## Membership & Built-in Functions

# %%
fruits = {"Apple", "Banana", "Mango"}
print("Apple" in fruits)
# Out:
# True

# %%
print(len(fruits))
# Out:
# 3

# %% [markdown]
# ## Subset, Superset & Disjoint

# %%
x = {1, 2}
y = {1, 2, 3, 4}
print(x.issubset(y))
# Out:
# True

# %%
print(y.issuperset(x))
# Out:
# True

# %%
z = {10, 11}
print(x.isdisjoint(z))
# Out:
# True

# %% [markdown]
# ## Converting Between Types

# %%
unique_list = list({1, 2, 2, 3})
print(unique_list)
# Out:
# [1, 2, 3]

# %%
names = ["Tom", "Jerry", "Tom", "Spike"]
unique_names = list(set(names))
print(unique_names)
# Out:
# ['Tom', 'Spike', 'Jerry']

# %% [markdown]
# ---
# ## Practice Questions

# %% [markdown]
# **Q1.** A survey recorded favourite fruits from 5 people as `["Apple", "Mango", "Apple", "Banana", "Mango"]`. Convert this list into a set and print the unique fruits.

# %%
# Write your code here
fruits = ["apple" , "mango", "apple" , "banana" , "mango"]
unique_list = set((fruits))
print(unique_list)
# Out:
# {'mango', 'banana', 'apple'}

# %% [markdown]
# **Q2.** `class_a = {"Riya", "Aman", "Kiran"}` and `class_b = {"Aman", "Sara", "Kiran", "Vikram"}` are students who play football in two classes. Print all students who play football in either class.

# %%
# Write your code here
class_a = {"Riya","Aman","kiran"}
class_b = {"Aman","Sara","Kiran","Vikram"}
print(class_a  | class_b)
# Out:
# {'kiran', 'Kiran', 'Vikram', 'Aman', 'Riya', 'Sara'}

# %% [markdown]
# **Q3.** Using the same two classes from Q2, print the students who play football in both classes.

# %%
# Write your code here
class_a = {"Riya","Aman","Kiran"}
class_b = {"Aman","Sara","Kiran","Vikram"}
print( class_a & class_b)
# Out:
# {'Kiran', 'Aman'}

# %% [markdown]
# **Q4.** Using the same two classes from Q2, print the students who play football only in Class A.

# %%
# Write your code here
class_a = {"Riya","Aman","Kiran"}
class_b = {"Aman","Sara","Kiran","Vikram"}
print(class_a - class_b)
# Out:
# {'Riya'}

# %% [markdown]
# **Q5.** A tuple of countries visited by a traveller is `("India", "USA", "France", "India", "UK")`. Convert it to a set and print how many unique countries were visited.

# %%
countries = ("India", "USA" , "France" , "India" , "Uk")
unique_countries = set((countries))
print(unique_countries)
# Out:
# {'France', 'India', 'Uk', 'USA'}

# %% [markdown]
# **Q6.** `books1 = {"Harry Potter", "Dune", "1984"}` and `books2 = {"Dune", "The Hobbit", "1984"}` are two friends' book collections. Print the books that only `books1` has.

# %%
book1 = {"Harry Potter" , "Dune" , "1984"}
book2 = {"Dune" , "The Hobbit" , "1984"}
print(book1-book2)
# Out:
# {'Harry Potter'}

# %% [markdown]
# **Q7.** A set of prime numbers less than 10 is `{2, 3, 5, 7}`. Add `11` to it and print the updated set.

# %%
# Write your code here
prime_numbers = {2,3,5,7}
prime_numbers.add(11)
print(prime_numbers)
# Out:
# {2, 3, 5, 7, 11}

# %% [markdown]
# **Q8.** `post1_tags = ["python", "coding", "tips"]` and `post2_tags = ["coding", "python", "beginners"]` are tags used on two blog posts. Convert both to sets and print the tags common to both posts.

# %%
post1_tags = ["python","coding","tips"]
post2_tags = ["coding","python","beginners"]

print(set(post1_tags)&set(post2_tags))
# Out:
# {'python', 'coding'}

# %% [markdown]
# **Q9.** A set of registered voter IDs is `{"V101", "V102", "V103"}`. Check whether `"V104"` is a registered voter.

# %%
Voter_Id = {"V101" , "V102" , "V103"}
print("V104" in Voter_Id)
# Out:
# False

# %% [markdown]
# **Q10.** A shopping list is `["Milk", "Bread", "Milk", "Eggs", "Bread", "Milk"]`. Print how many times `"Milk"` was bought, and then print the list of distinct items bought.

# %%
Shopping_list = ["Milk" , "Bread" , "Milk" , "Eggs" , "Bread" , "Milk"]
print(Shopping_list.count("Milk"))
print(list(set(Shopping_list)))
# Out:
# 3
# ['Eggs', 'Bread', 'Milk']
