# %% [markdown]
# ###Store your date of birth as a tuple in the format (day, month, year) and print it.

# %%
DOB = (31,8,2005)
print(DOB)
# Out:
# (31, 8, 2005)

# %% [markdown]
# ###A GPS location is given as (12.9716, 77.5946). Print the latitude and the longitude
# separately.

# %%
GPS = (12.9716, 77.5946)
print('latitude : ',GPS[0])
print('longitude : ',GPS[1])
# Out:
# latitude :  12.9716
# longitude :  77.5946

# %% [markdown]
# ###A product's details are stored as ("Laptop", 55000, "Electronics"). Print the price
# alone.

# %%
Details = ("Laptop" , 55000 , "Electronics")
print(Details[1])
# Out:
# 55000

# %% [markdown]
# ###Try changing the price in the tuple from the previous question directly to 60000. Run
# it, see what happens, and write down the result as a comment in your code.

# %%
Details = ("Laptop" , 55000 , "Electronics")
Details[1] = 60000
print(Details)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 Details = ("Laptop" , 55000 , "Electronics")
# ----> 2 Details[1] = 60000
#       3 print(Details)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ###A traffic light shows only three states: ("Red", "Yellow", "Green"). Print how many
# states it contains.

# %%
States = ("Red", "Yellow", "Green")
print(len(States))
# Out:
# 3

# %% [markdown]
# ###A movie's rating history is (4, 5, 3, 5, 5, 2). Print how many times it was rated 5.

# %%
rating = (4, 5, 3, 5, 5, 2)
print(rating.count(5))
# Out:
# 3

# %% [markdown]
# ###Convert the list ["Monday", "Tuesday", "Wednesday"] into a tuple and print it.

# %%
list = ["Monday", "Tuesday", "Wednesday"] 
converted_list = tuple(list)
print(converted_list)
# Out:
# ('Monday', 'Tuesday', 'Wednesday')

# %% [markdown]
# ###8. Store your name, age, and city together in a single tuple, then unpack it into three
# separate variables and print each one individually.

# %%
Details = ("shanib" , 22 , "mannarkkad")
Name = Details[0]
age = Details[1]
city = Details[2]
print('Name : ',Name)
print('age : ',age)
print('city : ',city)
# Out:
# Name :  shanib
# age :  22
# city :  mannarkkad

# %% [markdown]
# ###A store's opening and closing time are stored together as ("09:00 AM", "09:00 PM").
# Print the position of "09:00 PM" in the tuple.

# %%
Timing = ("09:00 AM", "09:00 PM")
print(Timing.index("09:00 PM"))
# Out:
# 1

# %% [markdown]
# ###Two friends share their favourite colours as color1 = ("Blue", "Green") and color2 =
# ("Red", "Yellow"). Combine both into a single tuple and print it.

# %%
color1 = ("Blue", "Green")
color2 = ("Red", "Yellow")
colors = (color1 + color2)
print(colors)
# Out:
# ('Blue', 'Green', 'Red', 'Yellow')

# %% [markdown]
# ###11. A recipe needs exactly three ingredients in a fixed order: ("Flour", "Sugar", "Eggs").
# Print the ingredients in reverse order without changing the original tuple.

# %%
order = ("Flour", "Sugar", "Eggs")
print(order[::-1])
# Out:
# ('Eggs', 'Sugar', 'Flour')

# %% [markdown]
# ###12. A student's marks in 3 subjects are given as (78, 85, 92). Print the total and the
# average.

# %%
Marks = (78, 85, 92)
b = len(Marks)
total = sum(Marks)
average = (total/b)
print('total : ',total)
print('average : ',average)
# Out:
# total :  255
# average :  85.0
