# %% [markdown]
# # Operators in Python — Practical Notebook

# %% [markdown]
# ## Arithmetic Operators

# %%
a = 10
b = 3
print(a + b)
# Out:
# 13

# %%
print(a - b)
# Out:
# 7

# %%
print(a * b)
# Out:
# 30

# %%
print(a / b)
# Out:
# 3.3333333333333335

# %%
print(a // b)
# Out:
# 3

# %%
print(a % b)
# Out:
# 1

# %%
print(a ** b)
# Out:
# 1000

# %% [markdown]
# ## Comparison Operators

# %%
x = 10
y = 20
print(x == y)
# Out:
# False

# %%
print(x != y)
# Out:
# True

# %%
print(x > y)
# Out:
# False

# %%
print(x < y)
# Out:
# True

# %%
print(x >= y)
# Out:
# True

# %%
print(x <= y)
# Out:
# True

# %% [markdown]
# ## Logical Operators

# %%
p = True
q = False
print(p and q)
# Out:
# False

# %%
print(p or q)
# Out:
# True

# %%
print(not p)
# Out:
# False

# %%
not (True or False)
# Out:
# False

# %% [markdown]
# ## Assignment Operators

# %%
num = 5
num += 3  # num = num + 3
print(num)
# Out:
# 8

# %%
num = 5
num -= 2   # num = num - 2
print(num)
# Out:
# 3

# %%
num = 5
num *= 6
print(num)
# Out:
# 30

# %%
num = 20
num /= 4
print(num)
# Out:
# 5.0

# %%
num = 20
num //== 3
print(num)
# Out:
# 6.666666666666667

# %%
num = 20
num %= 3
print(num)
# Out:
# 2

# %%
num = 2
num **= 3
print(num)
# Out:
# 8

# %% [markdown]
# ## Membership Operators

# %%
fruits = ["Apple", "Banana", "Mango"]
print("Apple" in fruits)
# Out:
# True

# %%
print("Grapes" not in fruits)
# Out:
# True

# %% [markdown]
# ## Identity Operators

# %%
a = [1, 2, 3]
b = a.copy()
b.append(5)
a
# Out:
# [1, 2, 3]

# %%
a = [1, 2, 3]
b = a
c = [1, 2, 3]
print(a is b)
# Out:
# True

# %%
print(a is c)
# Out:
# False

# %%
print(a == c)
# Out:
# True

# %%
a = 257
b = 257
a is b
# Out:
# False

# %% [markdown]
# ---
# ## Practice Questions

# %% [markdown]
# **Q1.** A shopkeeper sells an item for ₹450 that cost him ₹300. Print his profit.

# %%
selling_price = 450
cost = 300
print(selling_price - cost)
# Out:
# 150

# %% [markdown]
# **Q2.** Two exam scores are 78 and 85. Print whether the first score is greater than the second.

# %%
firstscore = 78
secondscore = 85
print(firstscore > secondscore)
# Out:
# False

# %% [markdown]
# **Q3.** A discount applies only if a customer is both a student AND a first-time buyer. Given `is_student = True` and `is_first_time = True`, print whether they qualify for the discount.

# %%
is_student = "True"
is_first_time = "True"
print(is_student and is_first_time)
# Out:
# True

# %% [markdown]
# **Q4.** A wallet balance starts at 1000. After spending 250, update the balance and print the new value.

# %%
wallet_balance_starts = 1000
spending_amount  = 250
balance_amount = (wallet_balance_starts - spending_amount)
print(balance_amount)
# Out:
# 750

# %% [markdown]
# **Q5.** A cart list is `["Milk", "Bread", "Eggs"]`. Check whether `"Butter"` is in the cart.

# %%
cart_list = ["Milk" , "Bread" , "Eggs"]
print("Butter" in cart_list)
# Out:
# False

# %% [markdown]
# **Q6.** `cart1 = ["Milk", "Bread"]` and `cart2 = cart1`. Check whether `cart1` and `cart2` refer to the exact same list in memory.

# %%
cart1 = ["Milk" , "Bread"]
cart2 = cart1
print(cart1 is cart2)
# Out:
# True

# %% [markdown]
# **Q7.** `cart3 = ["Milk", "Bread"]` holds the same values as `cart1` from Q6 but was created separately. Check whether `cart1` and `cart3` are equal in value, and separately check whether they are the same object in memory.

# %%
cart3 = ["Milk" , "Bread"]
print(cart3 == cart1)
print(cart3 is cart1)
# Out:
# True
# False

# %% [markdown]
# **Q8.** A train ticket costs ₹500 for adults and exactly half that for children. Print the child ticket price.

# %%
adult_ticket_cost = 500
adult_ticket_cost /=2
print(adult_ticket_cost)
# Out:
# 250.0

# %% [markdown]
# **Q9.** An account is flagged if the number of failed login attempts is 5 or more. Given `failed_attempts = 5`, print whether the account should be flagged.

# %%
failed_attempts = 5
print( failed_attempts >= 5,"account should be flagged")
# Out:
# True account should be flagged

# %% [markdown]
# **Q10.** A user is granted access if they are logged in OR have a guest pass. Given `is_logged_in = False` and `has_guest_pass = True`, print whether they are granted access.

# %%
is_logged_in = False
is_guest_pass = True
print(is_logged_in or is_guest_pass , "granted access" )
# Out:
# True granted access

# %% [markdown]
# **Q11.** A recipe requires `required = {"Flour", "Sugar", "Eggs"}`. A user has `ingredients = {"Flour", "Eggs", "Milk"}`. Print the ingredients that are common between the two.

# %%
required = {"Flour" , "sugar" , "Eggs"}
ingredients = {"Flour" , "Eggs" , "Milk"}
print(required & ingredients)
# Out:
# {'Flour', 'Eggs'}

# %% [markdown]
# **Q12.** A student's marks in two subjects are stored as `marks = (78, 85)`. Print whether the first subject's mark is not equal to the second.

# %%
marks = (78,85)
print(marks[0] != marks[1])
# Out:
# True
