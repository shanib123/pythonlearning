# %% [markdown]
# # Lists in Python — Practical Notebook

# %% [markdown]
# ## Creating Lists

# %%
data = []
print(data)
print(len(data))
print(type(data))
# Out:
# []
# 0
# <class 'list'>

# %%
numbers = [10, 20, 30, 40]
print(numbers)
# Out:
# [10, 20, 30, 40]
# 4

# %%
letters = list(("a", "b", "c"))
print(letters)
# Out:
# ['a', 'b', 'c']

# %%
mixed = [10, "Car", True, 10.5]
print(mixed)
# Out:
# [10, 'Car', True, 10.5]

# %%
nested = [[1, 2], [3, 4], [5, 6]]

nested[1][1]
# Out:
# 4

# %% [markdown]
# ## Indexing

# %%
fruits = ["Apple", "Banana", "Mango"]
print(fruits[0])
# Out:
# Apple

# %%
print(fruits[2])
# Out:
# Mango

# %%
print(fruits[-1])
# Out:
# Mango

# %% [markdown]
# ## Slicing

# %%
numbers = [10, 20, 30, 40, 50, 60]
print(numbers[1:4])
# Out:
# [20, 30, 40]

# %%
print(numbers[:3])
# Out:
# [10, 20, 30]

# %%
print(numbers[2:])
# Out:
# [30, 40, 50, 60]

# %%
print(numbers[:])
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
print(numbers[-3:])
# Out:
# [40, 50, 60]

# %%
print(numbers[::2])
# Out:
# [10, 30, 50]

# %%
print(numbers[::-1])
# Out:
# [60, 50, 40, 30, 20, 10]

# %% [markdown]
# ## Modifying Elements

# %%
fruits = ["Apple", "Banana", "Mango"]
print(fruits)
fruits[1] = "Orange"
print(fruits)
fruits[-1] = "kiwi"
fruits
# Out:
# ['Apple', 'Banana', 'Mango']
# ['Apple', 'Orange', 'Mango']
# ['Apple', 'Orange', 'kiwi']

# %% [markdown]
# ## List Methods

# %%
fruits = ["Apple", "Banana", "Mango"]
new = "kiwi"
fruits.insert(1,new)
fruits
# Out:
# ['Apple', 'kiwi', 'Banana', 'Mango']

# %%
my_list = [1, 2]
my_list.append(3)
print(my_list)
# Out:
# [1, 2, 3]

# %%
my_list = [1, 2]
my_list.extend([3, 4])
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
my_list = [1, 3]
my_list.insert(1, 2)
print(my_list)
# Out:
# [1, 2, 3]

# %%
my_list = [10, 22, 22, 40, 34, 33, 56]
a = 40
my_list.remove(a)
print(my_list)
# Out:
# [10, 22, 22, 34, 33, 56]

# %%
my_list = [1, 2, 3]
removed = my_list.pop(0)

print(my_list)
removed
# Out:
# [2, 3]
# 1

# %%
my_list = [1, 2, 3]
my_list.clear()
print(my_list)
# Out:
# []

# %%
my_list = [3, 1, 2]
my_list.sort()
print(my_list)
# Out:
# [1, 2, 3]

# %%
my_list = [3, 1, 2]
my_list.sort(reverse=True)
print(my_list)
# Out:
# [3, 2, 1]

# %%
my_list = [10, 33, 4,22, 56,6]
my_list.reverse() # my_list[::-1]
print(my_list)
# Out:
# [6, 56, 22, 4, 33, 10]

# %%
my_list = [1, 2, 1, 3]
print(my_list.count(1))
# Out:
# 2

# %%
my_list = [1, 2, 3]
print(my_list.index(2))
# Out:
# 1

# %%
original = [1, 2]
new_list = original.copy()
print(new_list)
# Out:
# [1, 2]

# %%
first = [1, 2, 4, 5]
second = first
second.append(78)
first
# Out:
# [1, 2, 4, 5, 78]

# %% [markdown]
# ## Built-in Functions

# %%
numbers = [10, 20, 30, 40]
print(len(numbers))
# Out:
# 4

# %%
print(max(numbers))
# Out:
# 40

# %%
print(min(numbers))
# Out:
# 10

# %%
print(sum(numbers))
# Out:
# 100

# %% [markdown]
# ## Operators

# %%
print(20 in numbers)
# Out:
# True

# %%
print(50 in numbers)
# Out:
# False

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
print(list1 + list2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list1 = [1, 2]
print(list1 * 3)
# Out:
# [1, 2, 1, 2, 1, 2]

# %% [markdown]
# ## List Comprehension

# %%
squares = [x*x for x in range(5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
even = [x for x in range(10) if x % 2 == 0]
print(even)

# %% [markdown]
# ---
# ## Practice Questions

# %% [markdown]
# **Q1.** Given `marks = [45, 67, 89, 32, 90, 12]`, sort them in descending order and print the result.

# %%
# Write your code here
marks=[45,67,89,32,90,12]
marks.sort()
print(marks)
# Out:
# [12, 32, 45, 67, 89, 90]

# %% [markdown]
# **Q2.** Given `cart = ["Notebook", "Pen"]`, use `append()` to add `"Eraser"` and `extend()` to add `["Sharpener", "Ruler"]`. Print the cart after each step.

# %%
# Write your code here
cart = ["notebook", "Pen"]
cart.append("Eraser")
print(cart)
cart.extend(["Sharpener","Ruler"])
print(cart)
# Out:
# ['notebook', 'Pen', 'Eraser']
# ['notebook', 'Pen', 'Eraser', 'Sharpener', 'Ruler']

# %% [markdown]
# **Q3.** What will be the output? Predict first, then run it to check.
#
# ```python
# list1 = [1, 2, 3, 4, 5]
# list2 = list1
# list2[0] = 100
# print(list1)
# ```
#
# Now fix it so that changing `list2` does NOT affect `list1`, using `.copy()`.

# %%
# Write/verify your code here
list1 = [1,2,3,4,5]
list2 = list1
list2[0] = 100
print(list1)
print(list2)
# Out:
# [100, 2, 3, 4, 5]
# [100, 2, 3, 4, 5]

# %% [markdown]
# **Q4.** What will be the output? Predict first, then run it to check.
#
# ```python
# a = [1, 2, 3]
# a.append([4, 5])
# print(len(a))
# ```

# %%
# Write/verify your code here
a = [1,2,3]
a.append([4,5])
print(len(a))
print(a)
# Out:
# 4
# [1, 2, 3, [4, 5]]

# %% [markdown]
# **Q5.** Given the list `[123, 22, 4, 55]`, write a program to find the second largest element.

# %%
# Write your code here
list =[123, 22, 4, 55]
list.sort()
print('second largest number is:',list[-1])
# Out:
# second largest number is: 123

# %% [markdown]
# **Q6.** Given the list `[5, 2, 8, 2, 5, 9, 8, 1]`, write a program to remove the duplicate values and print the unique list.

# %%
# Write your code here
a=[5,2,8,2,5,9,8,1]
b = list(set(a))
b
# Out:
# [1, 2, 5, 8, 9]

# %% [markdown]
# **Q7.** Given `names = ["Riya", "Aman", "Kiran", "Sara"]`, insert `"Meera"` at index 2 and print the updated list.

# %%
# Write your code here
names = ["Riya", "Aman", "kiran","sara"]
names.insert(2,"Meera")
print(names)
# Out:
# ['Riya', 'Aman', 'Meera', 'kiran', 'sara']

# %% [markdown]
# **Q8.** Given the list `[11, 22, 33, 44, 55]`, reverse it using slicing (do NOT use `.reverse()`).

# %%
# Write your code here
list=[11, 22, 33, 44, 55]
print(list[::-1])
# Out:
# [55, 44, 33, 22, 11]

# %% [markdown]
# **Q9.** Given `prices = [250, 100, 75, 500, 20]`, calculate and print the total bill amount using `sum()`.

# %%
# Write your code here
prices = [250,100,75,500,20]
print(sum(prices))
# Out:
# 945

# %% [markdown]
# **Q10.** Given `temperatures = [30, 32, 29, 35, 31, 28]`, print the highest and lowest temperature recorded.

# %%
# Write your code here
temperature=[30,32,29,35,31,28]
print("highest temp",max(temperature))
print('lowest temp',min(temperature))
# Out:
# highest temp 35
# lowest temp 28

# %% [markdown]
# **Q11.** You're storing a student's weekly attendance status (Present/Absent) that keeps changing every day. Would you use a list or a tuple for this? Write your answer as a comment, and create a sample list to demonstrate.

# %%
# Write your answer/code here
shanib=[]

# %%
attendance = input("enter present/absent :")
shanib.append(attendance)
print(shanib)
# Out:
# ['present', 'absent']

# %% [markdown]
# **Q12 (Bonus).** Ask the user to enter marks for 5 subjects one by one using `input()`, store them in a list, then print the total and average.

# %%
# Write your code here
a = float(input('enter the marks of 1st subject'))
b = float(input('enter the marks of 2nd subject'))
c = float(input('enter the marks of 3rd subject'))
d = float(input('enter the marks of 4th subject'))
e = float(input('enter the msrks of 5th subject'))

score = list((a,b,c,d,e))
print("total :",sum(score))
average = sum(score)/len(score)
print("average :",average)
# Out:
# total : 214.0
# average : 42.8

# %% [markdown]
# **Q13 (Bonus).** Given `numbers = list(range(1, 21))` (1 to 20), use list comprehension to create a list of squares of only the odd numbers.

# %%
# Write your code here
